# %% [markdown]
# # Forecasting in statsmodels
#
# Questo notebook descrive le previsioni utilizzando modelli di serie temporali in statsmodels.

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing 
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import KFold

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

#importing dataset
australia = pd.read_csv('AUS.csv', header = 0)

new_names = {'Date': 'date', 'Location': 'location','MinTemp': 'min_temp', 
            'MaxTemp': 'max_temp', 'Rainfall':'rainfall', 'Evaporation': 'evaporation', 'Sunshine': 'sunshine', 
            'WindGustDir':'wind_gust_dir', 'WindGustSpeed': 'wind_gust_speed', 'WindDir9am': 'wind_dir_9am', 'WindDir3pm': 'wind_dir_3pm',
            'WindSpeed9am': 'wind_speed_9am', 'WindSpeed3pm': 'wind_speed_3pm',
            'Humidity9am':'humidity_9am', 'Humidity3pm':'humidity_3pm', 'Pressure9am':'pressure_9am', 'Pressure3pm':'pressure_3pm',
            'Cloud9am':'cloud_9am', 'Cloud3pm':'cloud_3pm', 'Temp9am':'temp_9am', 'Temp3pm':'temp_3pm',
            'RainToday': 'rain_today', 'RainTomorrow': 'rain_tomorrow' }
australia.rename(columns=new_names, inplace=True)
australia = australia.drop(['sunshine','evaporation'], axis=1)

#correzione del campo wind_dir e wind_speed: mettiamo 0 al posto di null ai campi dir se la velocità del vento è 0 (non c'è vento in quel momento)
australia['wind_dir_9am'] = australia[['wind_dir_9am','wind_speed_9am']].apply(lambda x: '0' if x['wind_speed_9am']==0 else x['wind_dir_9am'], axis=1)
australia['wind_dir_3pm'] = australia[['wind_dir_3pm','wind_speed_3pm']].apply(lambda x: '0' if x['wind_speed_3pm']==0 else x['wind_dir_3pm'], axis=1)

# rimuoviamo i gust perchè sono presi dalle colonne sopra, tra il massimo della giornata
australia = australia.drop(['wind_gust_dir','wind_gust_speed'], axis=1)

#togliamo tutte quelle città che hanno almeno il 40% di null sul campo cloud3pm
location = australia.location.unique()
#print(location)
count = 0
for loc in location:
    #print(loc, len(australia[australia['location']==loc]))
    lung = len(australia[australia['location']==loc])
    if australia[australia['location']==loc].isnull().sum().cloud_3pm > lung * 0.4:
        australia = australia.drop(australia[australia['location'] == loc].index)
        count +=1

#australia = australia.dropna(thresh = 16)
australia = australia.ffill(axis=0)

#aggiungiamo la colonna state in funzione della città 

#stati:
sa = ['Adelaide', 'MountGambier', 'Nuriootpa', 'Woomera'] #australia meridionale
wa = ['Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport', 'Perth', 'SalmonGums',
      'Walpole'] #australia occidentale
nsw = ['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
       'Newcastle', 'NorahHead', 'Penrith', 'Richmond', 'Sydney', 'SydneyAirport',
       'WaggaWagga', 'Williamtown', 'Wollongong'] #Nuovo Galles del Sud
qld = ['Brisbane', 'Cairns', 'GoldCoast', 'Townsville'] #Queensland
tas = ['Hobart', 'Launceston'] #Tasmania
vic = ['Ballarat', 'Bendigo', 'Sale', 'Melbourne', 'MelbourneAirport',
      'Mildura', 'Nhil', 'Portland', 'Watsonia', 'Dartmoor'] #Victoria
act = ['Camberra', 'Tuggeranong', 'MountGinini'] #territorio della capitale australiana
nt = [ 'AliceSprings', 'Darwin', 'Katherine', 'Uluru'] #Territorio del nord
nfk = ['NorfolkIsland'] #territorio esterno del norfolk
 
#gli ultimi quattro si potrebbero unire anche in un unico territorio del sud est australiano,
#a livello di clima dovrebbero essere molto simii potrebbe avere difficoltà a classificarli

def State(a):
    if a in sa:
        return 'SA'
    elif a in wa:
        return 'WA'
    elif a in nsw:
        return 'NSW'
    elif a in qld:
        return 'QLD'
    elif a in tas:
        return 'TAS'
    elif a in vic:
        return 'VIC'
    elif a in act:
        return 'ACT'
    elif a in nt:
        return 'NT'
    elif a in nfk:
        return 'NFK'
    

#le = preprocessing.LabelEncoder()
#crime['category_id'] = le.fit_transform(australia['state'])

australia['state'] = australia.location.apply(lambda x: str(State(x)))

# %% [markdown]
# ### Preprocessing

# %%
#set della data come indice
australia['date'] = pd.to_datetime(australia['date'], infer_datetime_format=True)
australia = australia.set_index(['date'])

# scegliamo una tra tutte le città del nostro dataset 
aus1= australia[australia['location'] == 'Sydney']
aus2 = aus1.drop(aus1.columns.difference(['rainfall']), 1)

aus2.head()
# Out:
#             rainfall
# date
# 2008-02-01      15.6
# 2008-02-02       6.0
# 2008-02-03       6.6
# 2008-02-04      18.8
# 2008-02-05      77.4

# %%
#plot della rainfall per la città Sydney
from datetime import datetime
aus2.plot( y ='rainfall', figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# prendiamo un intervallo del dataset, che non contiene buchi temporali

from datetime import datetime
date_string1 = '2014-01-01'
dat1 = datetime.fromisoformat(date_string1)
date_string2 = '2017-01-01'
dat2 = datetime.fromisoformat(date_string2)
aus3= aus2[aus2.index >= dat1]
aus3= aus3[aus3.index < dat2]
len(aus3)
# Out:
# 1096

# %%
# facciamo una decomposizione additiva della serie temporale nelle sue 4 componenti

from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(aus3.rainfall, model = 'additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(15,15))

plt.subplot(411)
plt.plot(aus3.rainfall, label='Original')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')

plt.tight_layout()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(aus3.rainfall, model = 'additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

dfrom = '2014-01-01'
dfm = datetime.fromisoformat(dfrom)
dto = '2014-03-01'
dto = datetime.fromisoformat(dto)

plt.figure(figsize=(15,15))

plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.xlim([dfm, dto])
plt.legend(loc='best')


plt.tight_layout()

# %% [markdown]
# # STATIONARY TEST

# %% [markdown]
# #### ADF Test

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log
result = adfuller(aus3.rainfall.dropna())

print('ADF Statistic: %f' %result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -19.871087
# p-value: 0.000000

# %% [markdown]
# #### Phillips-Perron Testing

# %%
from arch.unitroot import PhillipsPerron

pp = PhillipsPerron(aus3.rainfall)
print(pp.summary().as_text())
# Out:
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                -21.609
# P-value                         0.000
# Lags                               22
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.86 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.

# %% [markdown]
# ### La serie stazionaria poichè il p-value < 0.05. Quindi settiamo d = 0

# %% [markdown]
# # Definizione dei parametri p, q per ARIMA

# %%
#par

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(12,5),'figure.dpi':120})

fig, axes = plt.subplots(1,2)
axes[0].plot(aus3.rainfall); axes[0].set_title('Original Series')
axes[0].get_xaxis().set_visible(False)

plot_pacf(aus3.rainfall, ax=axes[1], lags = 15)

plt.show()

# %% [markdown]
# #### il valore per noi interessante è p=1 poichè è quello che esce dall'area di significatività in modo evidente e impatta maggiormente sul valore attuale rispetto tutti gli altri.
# > p = 1

# %%
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize': (12, 5), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2)
axes[0].plot(aus3.rainfall); axes[0].set_title('Original series')
axes[0].get_xaxis().set_visible(False)
plot_acf(aus3.rainfall, ax=axes[1],lags=15)

plt.show()

# %% [markdown]
# #### Il valore per noi interessante è q=1 poichè è quello che esce dall'area di significatività in modo evidente e impatta maggiormente sul valore attuale rispetto tutti gli altri.
# > q = 1,2

# %% [markdown]
# ## Train - Test Split

# %%
from statsmodels.tsa.stattools import acf

l = int(len(aus3)*0.75)
train = aus3[:l]
test = aus3[l:]
print(l, len(aus3)-l)
# Out:
# 822 274

# %% [markdown]
# # ARIMA

# %%
from statsmodels.tsa.arima_model import ARIMA

# Construct the model
model1 = ARIMA(aus3.rainfall, order=(1, 0, 1)) # p, d, q
# Estimate the parameters
model_fit1 = model1.fit(disp = 0)

print(model_fit1.summary())
# Out:
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               rainfall   No. Observations:                 1096
# Model:                     ARMA(1, 1)   Log Likelihood               -4010.290
# Method:                       css-mle   S.D. of innovations              9.393
# Date:                Mon, 15 Mar 2021   AIC                           8028.580
# Time:                        19:37:05   BIC                           8048.577
# Sample:                    01-01-2014   HQIC                          8036.146
#                          - 12-31-2016
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              3.3018      0.440      7.505      0.000       2.440       4.164
# ar.L1.rainfall     0.2366      0.067      3.510      0.000       0.104       0.369
# ma.L1.rainfall     0.1841      0.067      2.744      0.006       0.053       0.316
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            4.2263           +0.0000j            4.2263            0.0000
# MA.1           -5.4309           +0.0000j            5.4309            0.5000
# -----------------------------------------------------------------------------

# %%
from statsmodels.tsa.arima_model import ARIMA

# Construct the model
model2 = ARIMA(aus3.rainfall, order=(1, 0, 2)) # p, d, q
# Estimate the parameters
model_fit2 = model2.fit(disp = 0)

print(model_fit2.summary())
# Out:
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               rainfall   No. Observations:                 1096
# Model:                     ARMA(1, 2)   Log Likelihood               -4009.288
# Method:                       css-mle   S.D. of innovations              9.385
# Date:                Mon, 15 Mar 2021   AIC                           8028.577
# Time:                        19:37:06   BIC                           8053.574
# Sample:                    01-01-2014   HQIC                          8038.035
#                          - 12-31-2016
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              3.3022      0.431      7.666      0.000       2.458       4.146
# ar.L1.rainfall    -0.1157      0.220     -0.526      0.599      -0.547       0.316
# ma.L1.rainfall     0.5389      0.218      2.477      0.013       0.113       0.965
# ma.L2.rainfall     0.1570      0.089      1.772      0.076      -0.017       0.331
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -8.6405           +0.0000j            8.6405            0.5000
# MA.1           -1.7156           -1.8504j            2.5234           -0.3690
# MA.2           -1.7156           +1.8504j            2.5234            0.3690
# -----------------------------------------------------------------------------

# %% [markdown]
# # Grid Search

# %%
import pmdarima as pm
sxmodel = pm.auto_arima(aus3.rainfall,
                           start_p=1, start_q=1,
                           test='adf',
                           max_p=1, max_q=2, m=7,
                           start_P=0, seasonal=True,
                           d=None, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)

# se numero di stagionalità > 0 --> P > 0
# se serie è stazionaria --> D = 1 altrimenti D = 0
# se numero di stagionalità > 0 --> Q = 0
# P + Q <= 2
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[7] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(0,0,0)(0,1,0)[7] intercept   : AIC=8893.964, Time=0.06 sec
#  ARIMA(1,0,0)(1,1,0)[7] intercept   : AIC=8365.978, Time=0.65 sec
#  ARIMA(0,0,1)(0,1,1)[7] intercept   : AIC=inf, Time=1.04 sec
#  ARIMA(0,0,0)(0,1,0)[7]             : AIC=8891.964, Time=0.05 sec
#  ARIMA(1,0,0)(0,1,0)[7] intercept   : AIC=8695.514, Time=0.22 sec
#  ARIMA(1,0,0)(2,1,0)[7] intercept   : AIC=8265.978, Time=1.36 sec
#  ARIMA(1,0,0)(2,1,1)[7] intercept   : AIC=inf, Time=3.97 sec
#  ARIMA(1,0,0)(1,1,1)[7] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(0,0,0)(2,1,0)[7] intercept   : AIC=8457.633, Time=0.81 sec
#  ARIMA(1,0,1)(2,1,0)[7] intercept   : AIC=8258.814, Time=1.45 sec
#  ARIMA(1,0,1)(1,1,0)[7] intercept   : AIC=8355.893, Time=0.69 sec
#  ARIMA(1,0,1)(2,1,1)[7] intercept   : AIC=inf, Time=4.51 sec
#  ARIMA(1,0,1)(1,1,1)[7] intercept   : AIC=inf, Time=1.35 sec
#  ARIMA(0,0,1)(2,1,0)[7] intercept   : AIC=8268.167, Time=1.39 sec
#  ARIMA(1,0,2)(2,1,0)[7] intercept   : AIC=8259.328, Time=4.62 sec
#  ARIMA(0,0,2)(2,1,0)[7] intercept   : AIC=8257.415, Time=1.28 sec
#  ARIMA(0,0,2)(1,1,0)[7] intercept   : AIC=8354.078, Time=0.62 sec
#  ARIMA(0,0,2)(2,1,1)[7] intercept   : AIC=inf, Time=3.60 sec
#  ARIMA(0,0,2)(1,1,1)[7] intercept   : AIC=inf, Time=1.02 sec
#  ARIMA(0,0,2)(2,1,0)[7]             : AIC=8255.415, Time=0.67 sec
#  ARIMA(0,0,2)(1,1,0)[7]             : AIC=8352.078, Time=0.27 sec
#  ARIMA(0,0,2)(2,1,1)[7]             : AIC=inf, Time=2.61 sec
#  ARIMA(0,0,2)(1,1,1)[7]             : AIC=inf, Time=1.38 sec
#  ARIMA(0,0,1)(2,1,0)[7]             : AIC=8266.167, Time=0.44 sec
#  ARIMA(1,0,2)(2,1,0)[7]             : AIC=8257.329, Time=1.54 sec
#  ARIMA(1,0,1)(2,1,0)[7]             : AIC=8256.815, Time=0.57 sec
#
# Best model:  ARIMA(0,0,2)(2,1,0)[7]
# Total fit time: 38.529 seconds

# %% [markdown]
# # ARIMA (0,0,2)

# %%
from statsmodels.tsa.arima_model import ARIMA

# Construct the model
model3 = ARIMA(aus3.rainfall, order=(0, 0, 2)) # p, d, q
# Estimate the parameters
model_fit3 = model3.fit(disp = 0)

print(model_fit3.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               rainfall   No. Observations:                 1096
# Model:                     ARMA(0, 2)   Log Likelihood               -4009.412
# Method:                       css-mle   S.D. of innovations              9.386
# Date:                Mon, 15 Mar 2021   AIC                           8026.824
# Time:                        19:48:07   BIC                           8046.822
# Sample:                    01-01-2014   HQIC                          8034.390
#                          - 12-31-2016
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              3.3020      0.435      7.583      0.000       2.449       4.155
# ma.L1.rainfall     0.4248      0.030     14.066      0.000       0.366       0.484
# ma.L2.rainfall     0.1117      0.031      3.594      0.000       0.051       0.173
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.9013           -2.3103j            2.9921           -0.3596
# MA.2           -1.9013           +2.3103j            2.9921            0.3596
# -----------------------------------------------------------------------------
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %% [markdown]
# # SARIMA (0, 0, 2) (2, 1, 0, 7)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Construct the model
model6 = SARIMAX(aus3.rainfall, order=(0, 0, 2),  seasonal_order=(2, 1, 0, 7))
# Estimate the parameters
model_fit6 = model6.fit()

print(model_fit6.summary())
# Out:
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                           rainfall   No. Observations:                 1096
# Model:             SARIMAX(0, 0, 2)x(2, 1, [], 7)   Log Likelihood               -4122.707
# Date:                            Mon, 15 Mar 2021   AIC                           8255.415
# Time:                                    19:37:46   BIC                           8280.380
# Sample:                                01-01-2014   HQIC                          8264.864
#                                      - 12-31-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.4432      0.014     32.224      0.000       0.416       0.470
# ma.L2          0.1103      0.027      4.045      0.000       0.057       0.164
# ar.S.L7       -0.6594      0.013    -50.155      0.000      -0.685      -0.634
# ar.S.L14      -0.2936      0.014    -21.236      0.000      -0.321      -0.266
# sigma2       113.3410      1.568     72.268      0.000     110.267     116.415
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             18689.97
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.74   Skew:                             2.31
# Prob(H) (two-sided):                  0.00   Kurtosis:                        22.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # RESIDUALS FOR ARIMA AND SARIMA

# %%
residuals = pd.DataFrame(model_fit3.resid)
rig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals for ARIMA", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
ax[1].set(xlim=(-10,10))
plt.show()

residuals = pd.DataFrame(model_fit6.resid)
rig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals for SARIMA", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
ax[1].set(xlim=(-10,10))
plt.show()

# %% [markdown]
# # FORECAST FOR ARIMA AND SARIMA

# %%
#ARIMA MODEL
model3 = ARIMA(train.rainfall, order=(0,0,2))
fitted = model3.fit(disp=-1)

#forecast
fc,se, conf = fitted.forecast(len(test), alpha=0.05) #95% conf

#make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:,0], index=test.index)
upper_series = pd.Series(conf[:,1], index=test.index)

#plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train.rainfall, label='training')
plt.plot(test.rainfall, label='actual')
plt.plot(fc_series, label='forecast')

plt.fill_between(lower_series.index, lower_series, upper_series,color='k', alpha=.15)
plt.title('ARIMA: Forecast vs Actuals')
plt.legend(loc='best')
# plt.legend(loc='uooer keft', fitsize=8)


dfrom = '2015-05-01'
dfm = datetime.fromisoformat(dfrom)
dto = '2016-05-01'
dto = datetime.fromisoformat(dto)
plt.xlim([dfm, dto])

plt.show()
# Out:
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
import statsmodels.api as sm
model7 = sm.tsa.SARIMAX(train.rainfall, order=(0,0,2), seasonal_order = (2,1,0,7)) 
res = model7.fit(start=test.index[0], end=test.index[-1]) #fittiamo il modello per stimare i parametri

fig, ax = plt.subplots(figsize=(15, 5))
plt.plot(train.index, train.rainfall, label='Train')
plt.plot(test.index, test.rainfall, label='Test')
plt.title('SARIMA: Forecast vs Actuals')

fcast = res.get_forecast(30).summary_frame() #prendo il 'summary_frame' perchè voglio plottare l'area di confidenza
fcast['mean'].plot(ax=ax, style='k--') #plotto la linea tratteggiata come la previsione fatta dal modello
ax.fill_between(fcast.index, fcast['mean_ci_lower'], fcast['mean_ci_upper'], color='k', alpha=0.05); #per poter plottare l'intervallo di confidenza inferiore e superiore

dfrom = '2015-05-01'
dfm = datetime.fromisoformat(dfrom)
dto = '2016-05-01'
dto = datetime.fromisoformat(dto)
plt.xlim([dfm, dto])

#plt.ylim([-5, 50])
# Out:
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# (16556.0, 16922.0)

# %% [markdown]
# # MODEL ACCURACY SCORE FOR SARIMA

# %%
def forecast_accuracy(forecast, actual):

    rmse= np.mean((forecast - actual)**2)**.5 #RMSE
    mbe = np.mean(forecast - actual) #MBE
    mae= np.mean(np.abs(forecast - actual)) #MAE
    
    #R-squared
    corr_matrix = np.corrcoef(actual, forecast)
    corr = corr_matrix[0,1]
    R_sq = corr**2
    
    return({'RMSE':rmse, 'MBE':mbe, 'MAE':mae, 'R-squared':R_sq })
    
forecast_accuracy(np.array(fcast['mean']), test.rainfall[:30].values)
# Out:
# {'RMSE': 17.22420888480143,
#  'MBE': 3.1096528937572527,
#  'MAE': 9.030891630672603,
#  'R-squared': 0.130653951299761}

# %% [markdown]
# # HWES

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing #HWES

model_hwes1 = ExponentialSmoothing(aus3.rainfall, seasonal='add', seasonal_periods=7)
hwes_fit1 = model_hwes1.fit()

print(hwes_fit1.summary())
# Out:
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                 rainfall   No. Observations:                 1096
# Model:             ExponentialSmoothing   SSE                         114558.901
# Optimized:                         True   AIC                           5113.766
# Trend:                             None   BIC                           5158.761
# Seasonal:                      Additive   AICC                          5114.010
# Seasonal Periods:                     7   Date:                 Mon, 15 Mar 2021
# Box-Cox:                          False   Time:                         19:50:48
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0874632                alpha                 True
# smoothing_seasonal           9.7164e-05                gamma                 True
# initial_level                 4.3936285                  l.0                 True
# initial_seasons.0            -3.2217202                  s.0                 True
# initial_seasons.1            -3.9896265                  s.1                 True
# initial_seasons.2            -4.1965940                  s.2                 True
# initial_seasons.3            -4.9372116                  s.3                 True
# initial_seasons.4            -5.0315480                  s.4                 True
# initial_seasons.5            -3.8159420                  s.5                 True
# initial_seasons.6            -3.8847038                  s.6                 True
# ---------------------------------------------------------------------------------
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

model_hwes1 = ExponentialSmoothing(train.rainfall, seasonal='add', seasonal_periods=7).fit()
pred = model_hwes1.predict(start=test.index[0], end=test.index[-1])

fig, ax = plt.subplots(figsize=(15, 5))
plt.plot(train.index, train.rainfall, label='Train')
plt.plot(test.index, test.rainfall, label='Test')
plt.plot(pred.index, pred, label='Holt-Winters')

dfrom = '2015-05-01'
dfm = datetime.fromisoformat(dfrom)
dto = '2016-05-15'
dto = datetime.fromisoformat(dto)
plt.xlim([dfm, dto])

plt.legend(loc='best')
# Out:
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing #HWES

model_hwes2 = ExponentialSmoothing(aus3.rainfall, seasonal='add', seasonal_periods=365)
hwes_fit2 = model_hwes2.fit()

print(hwes_fit2.summary())
# Out:
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                 rainfall   No. Observations:                 1096
# Model:             ExponentialSmoothing   SSE                          76168.542
# Optimized:                         True   AIC                           5382.444
# Trend:                             None   BIC                           7217.232
# Seasonal:                      Additive   AICC                          5758.560
# Seasonal Periods:                   365   Date:                 Mon, 15 Mar 2021
# Box-Cox:                          False   Time:                         19:51:53
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.1273081                alpha                 True
# smoothing_seasonal             0.0005096                gamma                 True
# initial_level                 -0.7645622                  l.0                 True
# initial_seasons.0             -6.8049036                  s.0                 True
# initial_seasons.1             -5.7179084                  s.1                 True
# initial_seasons.2             -5.3343730                  s.2                 True
# initial_seasons.3             -0.0965828                  s.3                 True
# initial_seasons.4              6.6790995                  s.4                 True
# initial_seasons.5              12.700490                  s.5                 True
# initial_seasons.6              9.5612544                  s.6                 True
# initial_seasons.7             -2.2830858                  s.7                 True
# initial_seasons.8             -4.8188585                  s.8                 True
# initial_seasons.9             -4.7637278                  s.9                 True
# initial_seasons.10             2.2107853                 s.10                 True
# initial_seasons.11            -1.6992324                 s.11                 True
# initial_seasons.12            -3.3219950                 s.12                 True
# initial_seasons.13            -4.9404004                 s.13                 True
# initial_seasons.14             6.4660001                 s.14                 True
# initial_seasons.15            -2.6337071                 s.15                 True
# initial_seasons.16            -4.5844254                 s.16                 True
# initial_seasons.17            -4.5858664                 s.17                 True
# initial_seasons.18            -4.5110616                 s.18                 True
# initial_seasons.19            -2.3146494                 s.19                 True
# initial_seasons.20             3.4041498                 s.20                 True
# initial_seasons.21             6.9463440                 s.21                 True
# initial_seasons.22             0.5379660                 s.22                 True
# initial_seasons.23            -3.8867071                 s.23                 True
# initial_seasons.24            -2.8708435                 s.24                 True
# initial_seasons.25            -3.7996491                 s.25                 True
# initial_seasons.26             7.9302793                 s.26                 True
# initial_seasons.27             15.476925                 s.27                 True
# initial_seasons.28             0.7786347                 s.28                 True
# initial_seasons.29            -0.8541905                 s.29                 True
# initial_seasons.30             0.6097211                 s.30                 True
# initial_seasons.31            -3.4771311                 s.31                 True
# initial_seasons.32            -1.7783197                 s.32                 True
# initial_seasons.33            -3.2046772                 s.33                 True
# initial_seasons.34             0.5293005                 s.34                 True
# initial_seasons.35             1.4888742                 s.35                 True
# initial_seasons.36            -2.2011165                 s.36                 True
# initial_seasons.37            -3.0991693                 s.37                 True
# initial_seasons.38            -3.0644800                 s.38                 True
# initial_seasons.39            -2.9654659                 s.39                 True
# initial_seasons.40            -2.8038915                 s.40                 True
# initial_seasons.41            -2.7143690                 s.41                 True
# initial_seasons.42            -2.6370862                 s.42                 True
# initial_seasons.43             0.7991330                 s.43                 True
# initial_seasons.44            -0.7452556                 s.44                 True
# initial_seasons.45            -1.9048082                 s.45                 True
# initial_seasons.46            -0.3514663                 s.46                 True
# initial_seasons.47             4.8155921                 s.47                 True
# initial_seasons.48            -2.4126223                 s.48                 True
# initial_seasons.49            -2.0997691                 s.49                 True
# initial_seasons.50             2.1971761                 s.50                 True
# initial_seasons.51             0.1299875                 s.51                 True
# initial_seasons.52            -1.1985699                 s.52                 True
# initial_seasons.53            -1.9877616                 s.53                 True
# initial_seasons.54            -1.8277299                 s.54                 True
# initial_seasons.55            -1.9245208                 s.55                 True
# initial_seasons.56            -0.4521575                 s.56                 True
# initial_seasons.57             8.7501356                 s.57                 True
# initial_seasons.58            -0.9005395                 s.58                 True
# initial_seasons.59             1.7603248                 s.59                 True
# initial_seasons.60             4.4057612                 s.60                 True
# initial_seasons.61             0.0234295                 s.61                 True
# initial_seasons.62            -0.9963465                 s.62                 True
# initial_seasons.63            -1.2961848                 s.63                 True
# initial_seasons.64            -0.7737032                 s.64                 True
# initial_seasons.65            -1.1924939                 s.65                 True
# initial_seasons.66            -1.1877926                 s.66                 True
# initial_seasons.67            -1.1204832                 s.67                 True
# initial_seasons.68            -0.9776893                 s.68                 True
# initial_seasons.69            -0.9586968                 s.69                 True
# initial_seasons.70            -0.7679676                 s.70                 True
# initial_seasons.71             8.4895247                 s.71                 True
# initial_seasons.72            -0.5525611                 s.72                 True
# initial_seasons.73            -0.7769362                 s.73                 True
# initial_seasons.74             9.6581113                 s.74                 True
# initial_seasons.75             8.7632080                 s.75                 True
# initial_seasons.76             4.2016974                 s.76                 True
# initial_seasons.77             0.7972555                 s.77                 True
# initial_seasons.78             1.1109859                 s.78                 True
# initial_seasons.79             0.5823171                 s.79                 True
# initial_seasons.80             20.655145                 s.80                 True
# initial_seasons.81             9.1627431                 s.81                 True
# initial_seasons.82             0.7388337                 s.82                 True
# initial_seasons.83             9.6423608                 s.83                 True
# initial_seasons.84             0.0611241                 s.84                 True
# initial_seasons.85             5.8319367                 s.85                 True
# initial_seasons.86             2.3119626                 s.86                 True
# initial_seasons.87             11.817909                 s.87                 True
# initial_seasons.88             0.4858791                 s.88                 True
# initial_seasons.89             8.5007910                 s.89                 True
# initial_seasons.90             2.6213804                 s.90                 True
# initial_seasons.91             0.1897230                 s.91                 True
# initial_seasons.92             0.3746315                 s.92                 True
# initial_seasons.93             8.3030047                 s.93                 True
# initial_seasons.94             40.812438                 s.94                 True
# initial_seasons.95             4.5445052                 s.95                 True
# initial_seasons.96             6.0034160                 s.96                 True
# initial_seasons.97             4.0747716                 s.97                 True
# initial_seasons.98             0.5960216                 s.98                 True
# initial_seasons.99             0.9275312                 s.99                 True
# initial_seasons.100            5.2054345                s.100                 True
# initial_seasons.101            2.4199252                s.101                 True
# initial_seasons.102            4.7726174                s.102                 True
# initial_seasons.103            2.0977248                s.103                 True
# initial_seasons.104            2.6280998                s.104                 True
# initial_seasons.105            11.273015                s.105                 True
# initial_seasons.106            1.3762064                s.106                 True
# initial_seasons.107            1.1709267                s.107                 True
# initial_seasons.108            2.4437041                s.108                 True
# initial_seasons.109            10.233092                s.109                 True
# initial_seasons.110            46.619433                s.110                 True
# initial_seasons.111            36.757164                s.111                 True
# initial_seasons.112            10.680398                s.112                 True
# initial_seasons.113            3.2571768                s.113                 True
# initial_seasons.114            4.8401042                s.114                 True
# initial_seasons.115            8.7013320                s.115                 True
# initial_seasons.116            2.7606449                s.116                 True
# initial_seasons.117            8.0185866                s.117                 True
# initial_seasons.118            1.1643347                s.118                 True
# initial_seasons.119            5.8733930                s.119                 True
# initial_seasons.120            10.939227                s.120                 True
# initial_seasons.121            5.1603156                s.121                 True
# initial_seasons.122            12.552274                s.122                 True
# initial_seasons.123            2.7953643                s.123                 True
# initial_seasons.124            1.4545220                s.124                 True
# initial_seasons.125            1.5776887                s.125                 True
# initial_seasons.126            1.5198930                s.126                 True
# initial_seasons.127            1.5219487                s.127                 True
# initial_seasons.128            3.9277671                s.128                 True
# initial_seasons.129            2.0959169                s.129                 True
# initial_seasons.130            1.7598569                s.130                 True
# initial_seasons.131            1.5129117                s.131                 True
# initial_seasons.132            5.1623527                s.132                 True
# initial_seasons.133            2.2058420                s.133                 True
# initial_seasons.134            1.5510245                s.134                 True
# initial_seasons.135            1.7825838                s.135                 True
# initial_seasons.136            1.7343194                s.136                 True
# initial_seasons.137            1.5471914                s.137                 True
# initial_seasons.138            1.6349713                s.138                 True
# initial_seasons.139            1.7109477                s.139                 True
# initial_seasons.140            1.6271401                s.140                 True
# initial_seasons.141            5.3428221                s.141                 True
# initial_seasons.142            9.8343715                s.142                 True
# initial_seasons.143            1.6119501                s.143                 True
# initial_seasons.144            1.5743250                s.144                 True
# initial_seasons.145            1.5743552                s.145                 True
# initial_seasons.146            1.6411490                s.146                 True
# initial_seasons.147            1.6374963                s.147                 True
# initial_seasons.148            1.5733706                s.148                 True
# initial_seasons.149            2.3953071                s.149                 True
# initial_seasons.150            2.4906384                s.150                 True
# initial_seasons.151            5.2074068                s.151                 True
# initial_seasons.152            11.604027                s.152                 True
# initial_seasons.153            2.0562536                s.153                 True
# initial_seasons.154            1.4584110                s.154                 True
# initial_seasons.155            25.535868                s.155                 True
# initial_seasons.156            37.731546                s.156                 True
# initial_seasons.157            27.205367                s.157                 True
# initial_seasons.158            2.0678580                s.158                 True
# initial_seasons.159            2.1939675                s.159                 True
# initial_seasons.160            6.6747667                s.160                 True
# initial_seasons.161            5.5033287                s.161                 True
# initial_seasons.162            1.6108347                s.162                 True
# initial_seasons.163            1.5836532                s.163                 True
# initial_seasons.164            3.2517794                s.164                 True
# initial_seasons.165            1.7075264                s.165                 True
# initial_seasons.166            2.6025006                s.166                 True
# initial_seasons.167            5.2107066                s.167                 True
# initial_seasons.168            2.1643798                s.168                 True
# initial_seasons.169            25.854768                s.169                 True
# initial_seasons.170            3.9816792                s.170                 True
# initial_seasons.171            14.790621                s.171                 True
# initial_seasons.172            2.9065684                s.172                 True
# initial_seasons.173            1.5564032                s.173                 True
# initial_seasons.174            1.5089307                s.174                 True
# initial_seasons.175            1.5041358                s.175                 True
# initial_seasons.176            3.8259013                s.176                 True
# initial_seasons.177            1.5341785                s.177                 True
# initial_seasons.178            1.5477056                s.178                 True
# initial_seasons.179            2.3582484                s.179                 True
# initial_seasons.180            1.6705347                s.180                 True
# initial_seasons.181            1.9330499                s.181                 True
# initial_seasons.182            1.5973806                s.182                 True
# initial_seasons.183            1.5962070                s.183                 True
# initial_seasons.184            1.5788100                s.184                 True
# initial_seasons.185            1.5435859                s.185                 True
# initial_seasons.186            3.0996389                s.186                 True
# initial_seasons.187            1.5453937                s.187                 True
# initial_seasons.188            13.100452                s.188                 True
# initial_seasons.189            9.1420517                s.189                 True
# initial_seasons.190            2.4334235                s.190                 True
# initial_seasons.191            2.0109324                s.191                 True
# initial_seasons.192            2.1755418                s.192                 True
# initial_seasons.193            3.0568772                s.193                 True
# initial_seasons.194            1.5831005                s.194                 True
# initial_seasons.195            1.9772605                s.195                 True
# initial_seasons.196            2.0081576                s.196                 True
# initial_seasons.197            7.1859504                s.197                 True
# initial_seasons.198            4.6691765                s.198                 True
# initial_seasons.199            1.5625869                s.199                 True
# initial_seasons.200            1.4684240                s.200                 True
# initial_seasons.201            8.0060172                s.201                 True
# initial_seasons.202            8.2882514                s.202                 True
# initial_seasons.203            2.1603953                s.203                 True
# initial_seasons.204            3.3456169                s.204                 True
# initial_seasons.205            1.3972895                s.205                 True
# initial_seasons.206            4.0218514                s.206                 True
# initial_seasons.207            2.6164870                s.207                 True
# initial_seasons.208            1.2588926                s.208                 True
# initial_seasons.209            1.2875521                s.209                 True
# initial_seasons.210            1.2739619                s.210                 True
# initial_seasons.211            1.2433018                s.211                 True
# initial_seasons.212            1.1878293                s.212                 True
# initial_seasons.213            1.1312715                s.213                 True
# initial_seasons.214            1.1838199                s.214                 True
# initial_seasons.215            9.2352026                s.215                 True
# initial_seasons.216            21.544435                s.216                 True
# initial_seasons.217            2.9493242                s.217                 True
# initial_seasons.218            1.6901052                s.218                 True
# initial_seasons.219            1.2152060                s.219                 True
# initial_seasons.220            1.0509051                s.220                 True
# initial_seasons.221            1.1024415                s.221                 True
# initial_seasons.222            1.1818168                s.222                 True
# initial_seasons.223            8.2119352                s.223                 True
# initial_seasons.224            7.3368205                s.224                 True
# initial_seasons.225            1.0374578                s.225                 True
# initial_seasons.226            1.1670707                s.226                 True
# initial_seasons.227            1.2737992                s.227                 True
# initial_seasons.228            12.579602                s.228                 True
# initial_seasons.229            8.2446111                s.229                 True
# initial_seasons.230            13.665517                s.230                 True
# initial_seasons.231            3.5971494                s.231                 True
# initial_seasons.232            4.7589550                s.232                 True
# initial_seasons.233            4.3356183                s.233                 True
# initial_seasons.234            2.7360410                s.234                 True
# initial_seasons.235            4.0518211                s.235                 True
# initial_seasons.236            20.053850                s.236                 True
# initial_seasons.237            24.300408                s.237                 True
# initial_seasons.238            5.6191607                s.238                 True
# initial_seasons.239            6.2480152                s.239                 True
# initial_seasons.240            1.3702001                s.240                 True
# initial_seasons.241            1.8425401                s.241                 True
# initial_seasons.242            1.7437130                s.242                 True
# initial_seasons.243            0.7254450                s.243                 True
# initial_seasons.244            0.7751038                s.244                 True
# initial_seasons.245            8.0437251                s.245                 True
# initial_seasons.246            15.596707                s.246                 True
# initial_seasons.247            2.4120205                s.247                 True
# initial_seasons.248            4.4995096                s.248                 True
# initial_seasons.249            6.7269849                s.249                 True
# initial_seasons.250            0.8554600                s.250                 True
# initial_seasons.251            0.6519478                s.251                 True
# initial_seasons.252            2.2628353                s.252                 True
# initial_seasons.253            0.9947725                s.253                 True
# initial_seasons.254            0.6018465                s.254                 True
# initial_seasons.255            0.7422274                s.255                 True
# initial_seasons.256            0.5609382                s.256                 True
# initial_seasons.257            2.3288233                s.257                 True
# initial_seasons.258            0.4102720                s.258                 True
# initial_seasons.259            0.3146300                s.259                 True
# initial_seasons.260            0.9998181                s.260                 True
# initial_seasons.261            3.8832945                s.261                 True
# initial_seasons.262            4.7934428                s.262                 True
# initial_seasons.263            0.7181631                s.263                 True
# initial_seasons.264            0.2978602                s.264                 True
# initial_seasons.265            0.8396231                s.265                 True
# initial_seasons.266            1.3415137                s.266                 True
# initial_seasons.267            10.827989                s.267                 True
# initial_seasons.268            2.9108604                s.268                 True
# initial_seasons.269            2.6140647                s.269                 True
# initial_seasons.270            0.1280548                s.270                 True
# initial_seasons.271           -0.0750130                s.271                 True
# initial_seasons.272            0.3481306                s.272                 True
# initial_seasons.273           -0.0067630                s.273                 True
# initial_seasons.274           -0.1877693                s.274                 True
# initial_seasons.275           -0.2314457                s.275                 True
# initial_seasons.276           -0.2615560                s.276                 True
# initial_seasons.277           -0.2917515                s.277                 True
# initial_seasons.278           -0.3263630                s.278                 True
# initial_seasons.279           -0.3624285                s.279                 True
# initial_seasons.280            1.3436068                s.280                 True
# initial_seasons.281           -0.4692329                s.281                 True
# initial_seasons.282           -0.4793611                s.282                 True
# initial_seasons.283           -0.5909715                s.283                 True
# initial_seasons.284            1.8916183                s.284                 True
# initial_seasons.285            0.0138618                s.285                 True
# initial_seasons.286            5.2550520                s.286                 True
# initial_seasons.287            22.615780                s.287                 True
# initial_seasons.288           -1.2588736                s.288                 True
# initial_seasons.289           -0.8646591                s.289                 True
# initial_seasons.290           -0.4090949                s.290                 True
# initial_seasons.291            0.0828210                s.291                 True
# initial_seasons.292           -0.8440959                s.292                 True
# initial_seasons.293           -0.6984664                s.293                 True
# initial_seasons.294            1.5734283                s.294                 True
# initial_seasons.295            7.6210492                s.295                 True
# initial_seasons.296           -1.0183598                s.296                 True
# initial_seasons.297           -1.1056090                s.297                 True
# initial_seasons.298           -1.5262557                s.298                 True
# initial_seasons.299            0.9933011                s.299                 True
# initial_seasons.300           -1.5224582                s.300                 True
# initial_seasons.301           -1.2455663                s.301                 True
# initial_seasons.302           -0.6863203                s.302                 True
# initial_seasons.303           -1.7390353                s.303                 True
# initial_seasons.304           -1.3985023                s.304                 True
# initial_seasons.305            7.6357729                s.305                 True
# initial_seasons.306           -1.5690109                s.306                 True
# initial_seasons.307           -0.8681537                s.307                 True
# initial_seasons.308            2.1933832                s.308                 True
# initial_seasons.309            2.2918533                s.309                 True
# initial_seasons.310            1.0152666                s.310                 True
# initial_seasons.311           -2.2894967                s.311                 True
# initial_seasons.312           -2.4829853                s.312                 True
# initial_seasons.313           -1.9029683                s.313                 True
# initial_seasons.314            0.7650591                s.314                 True
# initial_seasons.315           -1.8275850                s.315                 True
# initial_seasons.316            0.2811530                s.316                 True
# initial_seasons.317            3.3067445                s.317                 True
# initial_seasons.318            7.0452718                s.318                 True
# initial_seasons.319            0.6448845                s.319                 True
# initial_seasons.320           -3.0266552                s.320                 True
# initial_seasons.321           -3.1870854                s.321                 True
# initial_seasons.322           -3.2577311                s.322                 True
# initial_seasons.323           -3.3440930                s.323                 True
# initial_seasons.324           -3.4340096                s.324                 True
# initial_seasons.325           -3.5303100                s.325                 True
# initial_seasons.326           -3.6194391                s.326                 True
# initial_seasons.327           -3.7122306                s.327                 True
# initial_seasons.328           -0.3733290                s.328                 True
# initial_seasons.329           -3.8897541                s.329                 True
# initial_seasons.330           -3.6709164                s.330                 True
# initial_seasons.331           -3.9589707                s.331                 True
# initial_seasons.332           -4.0517862                s.332                 True
# initial_seasons.333           -4.1575480                s.333                 True
# initial_seasons.334           -3.2206137                s.334                 True
# initial_seasons.335           -1.6605622                s.335                 True
# initial_seasons.336           -4.0173024                s.336                 True
# initial_seasons.337            3.3635738                s.337                 True
# initial_seasons.338           -2.6765840                s.338                 True
# initial_seasons.339           -3.9182583                s.339                 True
# initial_seasons.340           -1.7961352                s.340                 True
# initial_seasons.341            3.0346299                s.341                 True
# initial_seasons.342           -4.3962833                s.342                 True
# initial_seasons.343            0.4412273                s.343                 True
# initial_seasons.344           -1.6359343                s.344                 True
# initial_seasons.345           -1.1089439                s.345                 True
# initial_seasons.346           -5.2495822                s.346                 True
# initial_seasons.347           -5.2823917                s.347                 True
# initial_seasons.348           -5.4103176                s.348                 True
# initial_seasons.349           -2.6371955                s.349                 True
# initial_seasons.350            8.6100503                s.350                 True
# initial_seasons.351           -1.9282530                s.351                 True
# initial_seasons.352           -5.6306684                s.352                 True
# initial_seasons.353           -5.8071936                s.353                 True
# initial_seasons.354           -5.8709140                s.354                 True
# initial_seasons.355            4.2617903                s.355                 True
# initial_seasons.356            5.7618177                s.356                 True
# initial_seasons.357           -4.8248272                s.357                 True
# initial_seasons.358           -5.5174437                s.358                 True
# initial_seasons.359            4.6214306                s.359                 True
# initial_seasons.360           -5.0954648                s.360                 True
# initial_seasons.361           -4.6416164                s.361                 True
# initial_seasons.362           -5.5498444                s.362                 True
# initial_seasons.363           -6.0002635                s.363                 True
# initial_seasons.364           -7.0888975                s.364                 True
# ----------------------------------------------------------------------------------

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

model_hwes2 = ExponentialSmoothing(train.rainfall, seasonal='add', seasonal_periods=365).fit()
pred = model_hwes2.predict(start=test.index[0], end=test.index[-1])

fig, ax = plt.subplots(figsize=(15, 5))
plt.plot(train.index, train.rainfall, label='Train')
plt.plot(test.index, test.rainfall, label='Test')
plt.plot(pred.index, pred, label='Holt-Winters')

dfrom = '2014-01-01'
dfm = datetime.fromisoformat(dfrom)
dto = '2017-01-01'
dto = datetime.fromisoformat(dto)
plt.xlim([dfm, dto])

plt.legend(loc='best')
# Out:
# C:\Users\angel\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %% [markdown]
# # RESIDUALS FOR HWES

# %%
residuals = pd.DataFrame(model_hwes2.resid)
rig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals for HWES", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
ax[1].set(xlim=(-10,10))
plt.show()

# %% [markdown]
# # MODEL ACCURACY SCORE FOR HWES

# %%
def forecast_accuracy(forecast, actual):

    rmse= np.mean((forecast - actual)**2)**.5 #RMSE
    mbe = np.mean(forecast - actual) #MBE
    mae= np.mean(np.abs(forecast - actual)) #MAE
    
    #R-squared
    corr_matrix = np.corrcoef(actual, forecast)
    corr = corr_matrix[0,1]
    R_sq = corr**2
    
    return({'RMSE':rmse, 'MBE':mbe, 'MAE':mae, 'R-squared':R_sq })
    
forecast_accuracy(np.array(pred), test.rainfall.values)
# Out:
# {'RMSE': 13.508447497897132,
#  'MBE': 3.4342999180587777,
#  'MAE': 7.945834113953157,
#  'R-squared': 0.011019721424521395}
